# %%
from redfin_scraper import RedfinScraper

# %%
scraper=RedfinScraper()
scraper.setup('JUNK')

# %%
scraper=RedfinScraper()
scraper.setup('./zip_code_database.csv')

# %%
scraper=RedfinScraper()
scraper.setup() # From Config

# %%
scraper=RedfinScraper()
scraper.setup(None)

# %%
scraper.setup() # Test for no re-download

# %%
scraper.scrape(city_states=None,zip_codes=['JUNK'])

# %%
scraper.scrape(city_states=None,zip_codes='JUNK')

# %%
scraper.scrape(city_states=['Omaha, NE'],zip_codes='JUNK')

# %%
scraper.scrape(city_states=None,zip_codes=['77002','JUNK','77003'])

# %%
scraper.scrape(city_states=['Omaha,NE'],zip_codes=None)

# %%
scraper.scrape(city_states=[('Houston', 'TX'),'JUNK, JUNKY'],zip_codes=None)

# %%
scraper.scrape(city_states=['junk, junky'],zip_codes=['77002'])

# %%
scraper.scrape() # From Config

# %%
for i in range(1,7):
    try:
        scraper.get_data(id=f"D00{i}")
    except:
        print("Failed")
# Out:
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed

# %%
from redfin_scraper import RedfinScraper

scraper=RedfinScraper()

scraper.setup()

# %%
zip_list=scraper.zip_database[(scraper.zip_database['decommissioned']==0) & (scraper.zip_database['type']=='STANDARD') & (scraper.zip_database['irs_estimated_population']>0)]['zip']

# %%
zip_list.shape[0]
# Out:
# 29358

# %%
zip_list=zip_list.reset_index()['zip']

# %%
scraper.scrape(zip_codes=list(zip_list[9000:11000]))
# Out:
#         index              SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0           0            MLS Listing        NaN   Mobile/Manufactured Home
# 1           1            MLS Listing        NaN   Mobile/Manufactured Home
# 2           2            MLS Listing        NaN   Mobile/Manufactured Home
# 3           3            MLS Listing        NaN   Mobile/Manufactured Home
# 4           4            MLS Listing        NaN   Mobile/Manufactured Home
# ...       ...                    ...        ...                        ...
# 167545    196  New Construction Plan        NaN  Single Family Residential
# 167546    197  New Construction Plan        NaN  Single Family Residential
# 167547    198  New Construction Plan        NaN  Single Family Residential
# 167548    199  New Construction Plan        NaN  Single Family Residential
# 167549    200  New Construction Plan        NaN  Single Family Residential
#
#                           ADDRESS        CITY STATE OR PROVINCE  \
# 0        2219 Evergreen Cir #1710    Zellwood                FL
# 1          4022 N Citrus Cir #683    Zellwood                FL
# 2       2218 Orangewood Cir #1540    Zellwood                FL
# 3          4204 Medalist Ct #1888    Zellwood                FL
# 4                 2567 Cayman Cir    Zellwood                FL
# ...                           ...         ...               ...
# 167545                   Pembroke  Mount Dora                FL
# 167546                    Bermuda  Mount Dora                FL
# 167547                 Margate II  Mount Dora                FL
# 167548                    Kinkade  Mount Dora                FL
# 167549                    Pollock  Mount Dora                FL
#
#        ZIP OR POSTAL CODE     PRICE  BEDS  ...  STATUS  \
# 0                   32798  349900.0   4.0  ...  Active
# 1                   32798  150000.0   2.0  ...  Active
# 2                   32798  115500.0   2.0  ...  Active
# 3                   32798  179000.0   2.0  ...  Active
# 4                   32798  295000.0   3.0  ...  Active
# ...                   ...       ...   ...  ...     ...
# 167545              32757  448990.0   4.0  ...  Active
# 167546              32757  515100.0   4.0  ...  Active
# 167547              32757  405990.0   3.0  ...  Active
# 167548              32757  601990.0   4.0  ...  Active
# 167549              32757  576990.0   4.0  ...  Active
#
#        NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                       ...
# 167545
# 167546
# 167547
# 167548
# 167549
#
#         URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0       https://www.redfin.com/FL/Zellwood/2219-Evergr...
# 1       https://www.redfin.com/FL/Zellwood/4022-N-Citr...
# 2       https://www.redfin.com/FL/Zellwood/2218-Orange...
# 3       https://www.redfin.com/FL/Zellwood/4204-Medali...
# 4       https://www.redfin.com/FL/Zellwood/2567-Cayman...
# ...                                                   ...
# 167545  https://www.redfin.com/FL/Mt-Dora/Summerbrooke...
# 167546  https://www.redfin.com/FL/Mt-Dora/Lakes-of-Mou...
# 167547  https://www.redfin.com/FL/Mt-Dora/Summerbrooke...
# 167548  https://www.redfin.com/FL/Mt-Dora/Dora-Parc/Ki...
# 167549  https://www.redfin.com/FL/Mt-Dora/Dora-Parc/Po...
#
#                    SOURCE            MLS#  FAVORITE  INTERESTED   LATITUDE  \
# 0             Stellar MLS        O6096010         N           Y  28.715641
# 1             Stellar MLS        O6095026         N           Y  28.717943
# 2             Stellar MLS        O6091433         N           Y  28.715529
# 3             Stellar MLS        O6093513         N           Y  28.724577
# 4             Stellar MLS        O6091265         N           Y  28.720874
# ...                   ...             ...       ...         ...        ...
# 167545  NewHomeSource.com  Plan-221935095         N           Y  28.807247
# 167546  NewHomeSource.com  Plan-221757572         N           Y  28.851147
# 167547  NewHomeSource.com  Plan-221935083         N           Y  28.807247
# 167548  NewHomeSource.com  Plan-221913382         N           Y  28.782100
# 167549  NewHomeSource.com  Plan-221913381         N           Y  28.782100
#
#         LONGITUDE
# 0      -81.564988
# 1      -81.577873
# 2      -81.571139
# 3      -81.581257
# 4      -81.572715
# ...           ...
# 167545 -81.619784
# 167546 -81.619970
# 167547 -81.619784
# 167548 -81.623100
# 167549 -81.623100
#
# [167550 rows x 28 columns]
